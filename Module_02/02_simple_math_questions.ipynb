# %% [markdown]
# # Exercises: Basic math
# Credit: This notebook is modified from Scientific Computing for Chemists website by Charles Weiss
#
# To work on this exercise, you can learn/practice basic Python from 02_simple_math_example.ipynb notebook.

# %% [markdown]
# ##Q1
# Calculate the distance between point (x2,y2) and the origin (x1,y1).
#
# where $ x2=23 $ and $ y2=81 $
#
# Hint : equation to calculate distance $r$
#
# $$ r= \sqrt{(\Delta x)^2 + (\Delta y)^2)} $$
#
# To use square root function, you will need to import `math` library. For example,
#
#
# ~~~python
# import math
# rsq=9
# r=math.sqrt(rsq)
# ~~~

# %% [markdown]
# ## Q2
# The following are the atomic numbers of lithium, carbon, and sodium. Assign each to a variable and use Python to evaluate each of the following.
#
# Li = 3, C = 6, and Na = 11
#
#          a) Is Li greater than C?
#          b) Is Na less than or equal to C?
#          c) Is either Li or Na greater than C?
#          d) Are both C and Na greater than Li?

# %% [markdown]
# ## Q3
# Create a list of even numbers from 18 → 88 including 88. Using list methods, perform the following transformations in order on the same list:
#
# a) Reverse the list
#
# b) Remove the last value (i.e., 18)
#
# c) Append 16

# %% [markdown]
# ## Q4
# Use for loop to prints out “PV = nRT” five times in the following format
#
#
#
#     1 PV = nRT
#     2 PV = nRT
#     3 PV = nRT
#     4 PV = nRT
#     5 PV = nRT

# %% [markdown]
# ## Q5
# This exercise involves I/O problems and making a plot.

# %% [markdown]
# ### Step 1
# Copy the snippet code below to a new cell. This code is to generate a test file containing simulated kinetics data.
#
# ~~~python
# import math
# with open('test.txt', 'a') as file:
#     file.write('time, [A] \n')
#     for t in range(20):
#         file.write('%s, %s \n' % (t, math.exp(-0.5*t)))
# ~~~

# %% [markdown]
# ### Step 2
#
# Load the data from test.txt into a pandas DataFrame and display its first few rows.
#
# ~~~python
# import pandas as pd
#
# df = pd.read_csv('filename')
# display(df.head())
# ~~~
#
# **Note:** you'll need to modify it.

# %% [markdown]
# ### Step 3.
# Making the plot of [A] versus time
#
# code snippet:
# ~~~python
# import matplotlib.pyplot as plt
#
# plt.figure(figsize=(10, 6))
# plt.plot(x, y)
# plt.xlabel('XXXXX')
# plt.ylabel('YYYYY')
# plt.title('plot title')
# plt.show()
# ~~~
#
# Here you will need to
# * define x and y
# * name the plot title
# * label x and y axes
