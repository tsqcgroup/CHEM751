# %% [markdown]
# # Visualize molecule with py3Dmol

# %% [markdown]
# ### Install and setup py3Dmol

# %%
# First, install the package
# !pip install -q py3Dmol

# %%
# Then import the required libraries
import py3Dmol
import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# ### Visualize using xyz coordinates

# %% [markdown]
# #### function to set up all variables for py3Dmol

# %%
def show_mol(atomspec):
  # visualize molecule
  view = py3Dmol.view(width=200, height=200)
  view.removeAllModels()
  view.addModel(atomspec, "xyz")
  view.setStyle({'stick': {}, 'sphere': {'scale': .30}})
  view.zoomTo()
  #view.zoom(0.8)
  view.show()

# %% [markdown]
# #### view molecule

# %%
# setup coordinates
atomspec = '''3
xyz coordinates
C   0.122391   -0.000000    0.088352
H  -0.125474   -0.000000    1.136866
H   1.039556    0.000000   -0.477002'''
# call show_mol function to visualize atomspec
show_mol(atomspec)
# Out:
# <div id="3dmolviewer_17514296121102946"  style="position: relative; width: 200px; height: 200px;">
#         <p id="3dmolwarning_17514296121102946" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.1/build/3Dmol-min.js');
# }
#
# var viewer_17514296121102946 = null;
# var warn = document.getElementById("3dmolwarning_17514296121102946");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17514296121102946 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17514296121102946"),{backgroundColor:"white"});
# viewer_17514296121102946.zoomTo();
# 	viewer_17514296121102946.removeAllModels();
# 	viewer_17514296121102946.addModel("3\nxyz coordinates\nC   0.122391   -0.000000    0.088352\nH  -0.125474   -0.000000    1.136866\nH   1.039556    0.000000   -0.477002","xyz");
# 	viewer_17514296121102946.setStyle({"stick": {}, "sphere": {"scale": 0.3}});
# 	viewer_17514296121102946.zoomTo();
# viewer_17514296121102946.render();
# });
# </script>

# %% [markdown]
# ### Visualize protein from Protein Drug Bank.
# See the example of a deoxy human hemoglobin:

# %%
view = py3Dmol.view(width=680, height=300, query='pdb:1A3N', linked=False)
view.setStyle({'cartoon':{'color':'spectrum'}})
view.setBackgroundColor('#FFFFFF')
view.show()
# Out:
# <div id="3dmolviewer_17514873948820639"  style="position: relative; width: 680px; height: 300px;">
#         <p id="3dmolwarning_17514873948820639" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.1/build/3Dmol-min.js');
# }
#
# var viewer_17514873948820639 = null;
# var warn = document.getElementById("3dmolwarning_17514873948820639");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17514873948820639 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17514873948820639"),{backgroundColor:"white"});
# $3Dmol.download("pdb:1A3N", viewer_17514873948820639, {}, function() {
# viewer_17514873948820639.zoomTo();
# 	viewer_17514873948820639.setStyle({"cartoon": {"color": "spectrum"}});
# 	viewer_17514873948820639.setBackgroundColor("#FFFFFF");
# viewer_17514873948820639.render();
# })
# });
# </script>

# %% [markdown]
# ### View molecule from [PubChem](https://pubchem.ncbi.nlm.nih.gov/)
# For more complex molecules, instead of manually representing them, it’s easier to pull them directly from sites like PubChem. In that case, all you need to do is define its id. See the example below for a cholesterol molecule:

# %%
cid_for_query = 'cid:5997'
view = py3Dmol.view(width=680, height=300, query=cid_for_query, linked=False)
view.setStyle({'stick': {}})
view.setBackgroundColor('#FFFFFF')
view.show()
# Out:
# <div id="3dmolviewer_17514874769556637"  style="position: relative; width: 680px; height: 300px;">
#         <p id="3dmolwarning_17514874769556637" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.1/build/3Dmol-min.js');
# }
#
# var viewer_17514874769556637 = null;
# var warn = document.getElementById("3dmolwarning_17514874769556637");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17514874769556637 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17514874769556637"),{backgroundColor:"white"});
# $3Dmol.download("cid:5997", viewer_17514874769556637, {}, function() {
# viewer_17514874769556637.zoomTo();
# 	viewer_17514874769556637.setStyle({"stick": {}});
# 	viewer_17514874769556637.setBackgroundColor("#FFFFFF");
# viewer_17514874769556637.render();
# })
# });
# </script>

# %% [markdown]
# ### More details
# You can see more examples how to use py3Dmol online. Here is one example.
#
#
# *   [Biomolecular Analysis with Python](https://lopezyse.medium.com/biomolecular-analysis-with-python-d278fd3b5bec)
