# %% [markdown]
# # <font color ='545aa7'> Basic Python </font>
#
# Credit: This notebook is modified from **Scientific Computing for Chemists** [website](https://weisscharlesj.github.io/SciCompforChemists/notebooks/introduction/intro.html) by Charles Weiss

# %%
8 + 3 * 2

# %%
(8 + 3) * 2

# %%
3 / 2

# %%
3 // 2

# %%
2 ** 3

# %%
10 % 3

# %% [markdown]
# ### 1.1.2 Integers & Floats

# %%
3 + 8

# %%
3.0 + 8

# %%
2 / 5

# %%
int(3.0)

# %%
float(4)

# %% [markdown]
# ### 1.1.3 Python Functions

# %%
abs(-4)

# %%
print(8.3145)

# %%
import math
math.sqrt(4)

# %%
math.ceil(4.3)

# %%
math.pi

# %%
math.pow(2, 8)

# %%
from math import radians
radians(4)

# %%
a = 5.0
b= 3

# %%
a + b

# %% [markdown]
# ### 1.2.2 Compound Assignment

# %%
x = 5
y = x

# %%
y

# %%
x = 8

# %%
y

# %%
text = "some text"

# %%
print(text)

# %%
str(4)

# %%
'4' + '2'

# %%
'4' * 2

# %% [raw]
# '4' * '2'

# %%
int('4') * int('2')

# %%
len(text)

# %%
print(str(4.0) + ' g')

# %%
print(4.0, 'g')

# %% [markdown]
# ### 1.3.2 Indexing & Slicing

# %%
seq = 'MSLFKIRMPE'

# %%
seq[0]

# %%
'MSLFKIRMPE'[1]

# %%
len(seq)

# %%
seq[9]

# %%
seq[-1]

# %%
seq[0:5]

# %%
file = '1rxt.pdb'

# %%
file[-3:-1]

# %%
file[-3:]

# %%
file[:-4]

# %%
seq[::2]

# %% [markdown]
# ### 1.3.3 String Methods

# %%
quote = 'anyone who has never made a mistake has never tried anything new.'

# %%
quote.capitalize()

# %%
quote

# %%
cap_quote = quote.capitalize()

# %%
cap_quote

# %%
str.isalpha(quote)

# %%
str.capitalize(quote)

# %%
8 == 3

# %%
8 > 3

# %%
8 == 8.0

# %%
8 is 8.0

# %% [markdown]
# ### 1.4.2 Compound Comparisons

# %%
True and False

# %%
True or False

# %%
8 > 3 or 8 < 2

# %%
not 8 > 3

# %% [markdown]
# ### 1.4.3 Alternative Truth Representations

# %%
bool(1)

# %%
bool(0)

# %%
bool(5)

# %% [markdown]
# ### 1.4.4 any() & all()

# %%
any([True, True, False])

# %%
all([True, True, False])

# %%
all([True, True, True])

# %%
any([0, 1, 0])

# %% [markdown]
# ### Test for Inclusion

# %%
comp1 = 'Co(NH3)6'
comp2 = 'Ni(H2O)6'

# %%
'Ni' in comp1

# %%
'Ni' in comp2

# %%
x = 7

# %%
if x > 5:
    y = x **2
    print(y)

# %%
x = 3

# %%
if x > 5:
    y = x **2
    print(y)

# %% [markdown]
# ### 1.5.2 else Statements

# %%
pH = 9

# %%
if pH == 7:
    print('The solution is neutral.')

# %%
if pH == 7:
    print('The solution is neutral.')
elif pH > 7:
    print('The solution is basic.')
else:
    print('The solution is acidic.')

# %%
mass = [1.01, 4.00, 6.94, 0.01, 10.81, 12.01]

# %%
mass

# %%
EN = [2.1, 'NA', 1.0, 1.5, 2.0, 2.5]

# %%
EN

# %% [markdown]
# ### 1.6.2 Indexing & Slicing List

# %%
EN[0]

# %%
EN[1]

# %%
EN[0:3]

# %%
EN[3:5]

# %%
EN[3:]

# %% [markdown]
# ### 1.6.3 List Methods

# %%
mass = [4.00, 1.01, 6.94, 14.01, 10.81, 12.01, 9.01]

# %%
mass.sort()
mass

# %%
mass.reverse()
mass

# %%
mass.append(16.00)
mass

# %%
mass.extend([19.00, 20.18])
mass

# %%
mass.append([23.00, 24.31])
mass

# %% [markdown]
# ### 1.6.4 range Objections

# %%
a = range(10)
print(a)

# %%
list(a)

# %%
list(range(3,12))

# %%
list(range(3,20,3))

# %%
list(range(10,3,-1))

# %%
ten = range(10)

# %%
ten[2]

# %% [markdown]
# ### 1.6.5 Tuples

# %%
nrg = (-2.18e-18, -5.45e-19, -2.42e-19, -1.36e-19, -8.72e-20)

# %%
nrg[1] - nrg[0]

# %%
nrg[4] - nrg[3]

# %% [markdown]
# ## 1.7 Loops
# ### 1.7.1 for Loops

# %%
for value in [4, 6, 2]:
    print(2 * value)

# %%
2 * [4, 6, 2] # scalar multiplies vector

# %%
U235 = 183.2
for x in range(6):
    U235 = U235 / 2
    print('number of half-lives ' + str(x+1) +',' +str(U235) + ' g of U235 remains')

# %%
for letter in 'Linus':
    print(letter.capitalize())

# %% [markdown]
# ### Loops with math functions
# $\lambda=\frac{1}{1.097 \times 10^{-2} \times ( 0.25 - \frac{1}{n^{2}} ) }$
#  where $n=3,4,...,7$

# %%
for n in range(3,8):
    print(n)
    lam = 1 / (1.097e-2 * (0.25 - (1/n**2)))
    #print(lam)

# %% [markdown]
# ###  $X=A ^{2}$

# %%
numbers_A = [1, 2, 3, 4, 5, 6]  # original values
squares_A = []  # an empty list

# %%
len(numbers_A) # array size of numbers
for i in range(len(numbers_A)):
    print(f"Index: {i}, numbers_A[{i}]= {numbers_A[i]}")

# %%
for value in numbers_A:
    squares_A.append(value**2)

# %%
squares_A

# %% [markdown]
# ### 1.7.2 while Loops

# %%
x = 0
while x < 10:
    print(x)
    x = x + 2  # increments by 2

# %% [markdown]
# ### 1.7.3 Continue, Pass, & Break Commands

# %%
vol_OH = 35
vol_H = 0

for ml in range(1, 50):
    vol_total = vol_OH + vol_H
    mol_OH = 0.9 * vol_OH / 1000
    mol_H = 1.0 * vol_H / 1000
    if mol_H >= mol_OH:
        break
    else:
        vol_H = vol_H + 1

print('Endpoint: ' + str(vol_H) + ' mL HCl solution')

# %%
numbers = [1,2,3,4,5,6,7]
for number in numbers:
    if number % 2 == 1: # mod(number,2)
        continue
    print(math.sqrt(number))

# %% [markdown]
# ## 1.8 File I/O
# ### 1.8.1.Reading Lines

# %%
file = open('squares.csv')
for line in file.readlines():
    print(line)
file.close()

# %%
file = open('squares.csv')

numbers = []
squares = []

for line in file.readlines():
    fields = line.split(',')# splits line at comma
    numbers.append(int(fields[0]))
    squares.append(int(fields[1]))

file.close()

# %%
numbers

# %%
squares

# %% [markdown]
# ### 1.8.2 Using np.genfromtxt
# It's function to load data from csv and save to matrix `file`.
#
# Array dimension, shape, and size: https://note.nkmk.me/en/python-numpy-ndarray-ndim-shape-size/

# %%
import numpy as np

# %%
file = np.genfromtxt('squares.csv', delimiter=',')
file
# What are the dimensions, shape, and size of 'file'?

# %%
file[4][1]

# %%
# skip loading the first two rows
file = np.genfromtxt('header_file.csv', delimiter=',', skip_header=2)
file

# %% [markdown]
# ## 1.9 Creating Functions
# ### 1.9.1 Basic Functions

# %%
import math

# %% [markdown]
# The distance between two points from xyz coordinates
#
# $r=\sqrt{(x_{2}-x_{1})^{2} +(y_{2}-y_{1})^{2} +(z_{2}-z_{1})^{2}}$

# %%
def distance(coords1, coords2):
# changes along the x, y, and z coordinates
    dx = coords1[0] - coords2[0]
    dy = coords1[1] - coords2[1]
    dz = coords1[2] - coords2[2]

    d = math.sqrt(dx**2 + dy**2 + dz**2)

    print('The distance is: ' + str(d))

# %%
distance((1,2,3), (4,5,6))

# %%
distance((5,2,3), (7, 5.3, 9))

# %% [markdown]
# ### 1.9.2 return Statements

# %%
def distance(coords1, coords2):
# changes along the x, y, and z coordinates
    dx = coords1[0] - coords2[0]
    dy = coords1[1] - coords2[1]
    dz = coords1[2] - coords2[2]

    d = math.sqrt(dx**2 + dy**2 + dz**2)

    return d

# %%
distance([5,6,7], [3,2,1])

# %%
dist = distance([5,6,7], [3,2,1])

# %%
dist

# %%
pairs = (((1,2,3),(2,3,4)), ((3,7,1), (9,3,0)), ((0,0,1), (5,2,7)))

# %%
dist_list = []
for pair in pairs:
    dist = distance(pair[0], pair[1])
    dist_list.append(dist)

# %%
avg = sum(dist_list)/len(dist_list)

# %%
avg

# %% [markdown]
# ### 1.9.3 Local Variable Scope

# %%
def roots(numbers):
    for number in numbers:
        value = math.sqrt(number)
        square_roots.append(value)

# %%
square_roots = []

# %%
roots(range(10))

# %%
square_roots

# %% [markdown]
# ### 1.9.4 Arguments

# %%
def isotope(protons, neutrons):
    elements = ('H', 'He', 'Li', 'Be', 'B', 'C', 'N', 'O', 'F', 'Ne')
    symbol = elements[protons - 1]
    mass = protons + neutrons

    print(str(mass) + symbol)

# %%
isotope(6, 7)

# %%
isotope(7,6)

# %%
def isotope(protons=1, neutrons=0):
    elements = ('H', 'He', 'Li', 'Be', 'B', 'C', 'N', 'O', 'F', 'Ne')
    symbol = elements[protons - 1]
    mass = protons + neutrons

    print(str(mass) + symbol)

# %%
isotope(protons=1, neutrons=2)

# %%
isotope(neutrons=2, protons=1)

# %%
isotope()

# %%
isotope(neutrons=2)

# %% [markdown]
# ### 1.9.5 Docstrings

# %%
def distance(coords1, coords2):
    '''(list/tuple, list/tuple) -> float
    Takes in the xyz coordinates as lists or tuples for two atoms and returns the distance between them.

    distance((1,2,3), (4,5,6)) -> 5.196152422706632
    '''

    # changes along the x, y, and z coordinates
    dx = coords1[0] - coords2[0]
    dy = coords1[1] - coords2[1]
    dz = coords1[2] - coords2[2]
    d = math.sqrt(dx**2 + dy**2 + dz**2)

    return d
